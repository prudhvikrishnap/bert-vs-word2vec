# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/nyt_new.csv")
df.head(5)
# Out:
#                                             abstract  \
# 0  The gunman who shot two parishioners at the We...
# 1  Congress could do much more to protect America...
# 2  The tobacco and vaping industries and conserva...
# 3  Christina Iverson and Jeff Chen ring in the Ne...
# 4  Corrections that appeared in print on Wednesda...
#
#                                              snippet  \
# 0  The gunman who shot two parishioners at the We...
# 1  Congress could do much more to protect America...
# 2  The tobacco and vaping industries and conserva...
# 3  Christina Iverson and Jeff Chen ring in the Ne...
# 4  Corrections that appeared in print on Wednesda...
#
#                                       lead_paragraph document_type  \
# 0  WHITE SETTLEMENT, Texas — Given West Freeway C...       article
# 1  Congress invited predatory for-profit colleges...       article
# 2  The Trump administration is expected to announ...       article
# 3  WEDNESDAY PUZZLE — The weekend columnist Caitl...       article
# 4  An “On This Day in History” item on Tuesday ab...       article
#
#   type_of_material                                                uri  \
# 0             News  nyt://article/22fc94cd-2e4a-5af1-89f8-7260bf27...
# 1        Editorial  nyt://article/69a7090b-9f36-569e-b5ab-b0ba5bb3...
# 2             News  nyt://article/42d25485-0e48-50bf-8d16-948833b2...
# 3             News  nyt://article/9edddb54-0aa3-5835-a833-d311a76f...
# 4       Correction  nyt://article/16ebc00a-01f2-5f35-905f-15d299e5...
#
#                                        headline.main  \
# 0  ‘Battling a Demon’: Drifter Sought Help Before...
# 1                        Protect Veterans From Fraud
# 2  F.D.A. Plans to Ban Most E-Cigarette Flavors b...
# 3                             ‘It’s Green and Slimy’
# 4                          Corrections: Jan. 1, 2020
#
#                          headline.print_headline
# 0    Church Had Welcomed the Man Who Opened Fire
# 1                    Protect Veterans From Fraud
# 2  U.S. Set to Ban Vaping Flavors Teens Use Most
# 3                                            NaN
# 4                                    Corrections

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df.shape
# Out:
# (153060, 8)

# %%
df1 = df.dropna()

# %%
df1.shape
# Out:
# (85845, 8)

# %%
df1['document_type']=df1['document_type'].replace(['article'],1)
df1['document_type']=df1['document_type'].replace(['audio'],2)
df1['document_type']=df1['document_type'].replace(['multimedia'],3)
df1['document_type']=df1['document_type'].replace(['audiocontainer'],4)
df1['document_type']=df1['document_type'].replace(['News'],5)
# Out:
# <ipython-input-22-c20bf4640d15>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['document_type']=df1['document_type'].replace(['article'],1)
# <ipython-input-22-c20bf4640d15>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['document_type']=df1['document_type'].replace(['audio'],2)
# <ipython-input-22-c20bf4640d15>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['document_type']=df1['document_type'].replace(['multimedia'],3)
# <ipython-input-22-c20bf4640d15>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['document_type']=df1['document_type'].replace(['audiocontainer'],4)
# <ipython-input-22-c20bf4640d15>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['document_type']=df1['document_type'].replace(['News'],5)

# %%
df1.tail(5)
# Out:
#                                                  abstract  \
# 153046  Readers react to an editorial arguing that pol...
# 153050  The president traveled to Cambodia hoping that...
# 153052  In a country where protests are banned, hundre...
# 153056  The candidates will have to deal with a mix of...
# 153059  Working in the restaurant industry taught me s...
#
#                                                   snippet  \
# 153046  Readers react to an editorial arguing that pol...
# 153050  The president traveled to Cambodia hoping that...
# 153052  In a country where protests are banned, hundre...
# 153056  The candidates will have to deal with a mix of...
# 153059  Working in the restaurant industry taught me s...
#
#                                            lead_paragraph  document_type  \
# 153046                                     To the Editor:              1
# 153050  PHNOM PENH, Cambodia — President Biden told me...              1
# 153052  SHARM EL SHEIKH, Egypt — Hundreds of activists...              1
# 153056  ATLANTA — Georgia voters should be forgiven fo...              1
# 153059  Recently, a friend of mine who is newly divorc...              1
#
#        type_of_material                                                uri  \
# 153046           Letter  nyt://article/9a509deb-2a3f-5ace-afd1-b470b575...
# 153050             News  nyt://article/7a90fc9f-b734-5f3e-96d2-4d4cbdc1...
# 153052             News  nyt://article/4fa30afa-556c-59f6-865b-25ecaaf9...
# 153056             News  nyt://article/23c6d0c7-2884-5cef-925b-6148faef...
# 153059            Op-Ed  nyt://article/9129d384-2b22-5e9f-81b1-542a2343...
#
#                                             headline.main  \
# 153046                         Violence and Our Democracy
# 153050  In His 3rd Summit With Southeast Asian Leaders...
# 153052  U.N. Climate Summit Leads to a Rarity in Egypt...
# 153056  For Weary Georgia Voters, Senate Runoff Brings...
# 153059                 How I Learned the Art of Seduction
#
#                                   headline.print_headline
# 153046                         Violence and Our Democracy
# 153050  In 3rd Summit With Southeast Asian Leaders, Bi...
# 153052  Rarity in Egypt: Open Protest At the U.N. Clim...
# 153056  Georgians Approach Another Runoff With Wearine...
# 153059                 How I Learned the Art of Seduction

# %%
df1['document_type'].dtypes
# Out:
# dtype('int64')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df1['abstract'],df1['document_type'], stratify=df1['document_type'])

# %%
import tensorflow_hub as hub
import tensorflow_text as text

# %%
bert_preprocess = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
bert_encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4")

# %%
import tensorflow as tf

# %%
text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
preprocessed_text = bert_preprocess(text_input)
outputs = bert_encoder(preprocessed_text)

# %%
l = tf.keras.layers.Dropout(0.1, name="dropout")(outputs['pooled_output'])
l = tf.keras.layers.Dense(1, activation='sigmoid', name="output")(l)

# %%
model = tf.keras.Model(inputs=[text_input], outputs = [l])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text (InputLayer)              [(None,)]            0           []
#
#  keras_layer (KerasLayer)       {'input_type_ids':   0           ['text[0][0]']
#                                 (None, 128),
#                                  'input_word_ids':
#                                 (None, 128),
#                                  'input_mask': (Non
#                                 e, 128)}
#
#  keras_layer_1 (KerasLayer)     {'default': (None,   109482241   ['keras_layer[1][0]',
#                                 768),                             'keras_layer[1][1]',
#                                  'encoder_outputs':               'keras_layer[1][2]']
#                                  [(None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768)],
#                                  'pooled_output': (
#                                 None, 768),
#                                  'sequence_output':
#                                  (None, 128, 768)}
#
#  dropout (Dropout)              (None, 768)          0           ['keras_layer_1[1][13]']
#
#  output (Dense)                 (None, 1)            769         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 109,483,010
# Trainable params: 769
# Non-trainable params: 109,482,241
# __________________________________________________________________________________________________

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall')
]

model.compile(optimizer='adam',
 loss='binary_crossentropy',
 metrics=METRICS)

# %%
model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/15
# 2012/2012 [==============================] - 691s 338ms/step - loss: -2.9106 - accuracy: 0.9861 - precision: 1.0000 - recall: 0.9974
# Epoch 2/15
# 2012/2012 [==============================] - 678s 337ms/step - loss: -10.8993 - accuracy: 0.9877 - precision: 1.0000 - recall: 0.9990
# Epoch 3/15
# 2012/2012 [==============================] - 679s 337ms/step - loss: -19.6788 - accuracy: 0.9877 - precision: 1.0000 - recall: 0.9990
# Epoch 4/15
# 2012/2012 [==============================] - 675s 335ms/step - loss: -28.5904 - accuracy: 0.9878 - precision: 1.0000 - recall: 0.9991
# Epoch 5/15
# 2012/2012 [==============================] - 676s 336ms/step - loss: -37.3654 - accuracy: 0.9877 - precision: 1.0000 - recall: 0.9990
# Epoch 6/15
# 2012/2012 [==============================] - 676s 336ms/step - loss: -46.1907 - accuracy: 0.9877 - precision: 1.0000 - recall: 0.9990
# Epoch 7/15
# 2012/2012 [==============================] - 678s 337ms/step - loss: -55.1085 - accuracy: 0.9878 - precision: 1.0000 - recall: 0.9991
# Epoch 8/15
# 2012/2012 [==============================] - 678s 337ms/step - loss: -64.0152 - accuracy: 0.9877 - precision: 1.0000 - recall: 0.9990
# Epoch 9/15
# 2012/2012 [==============================] - 678s 337ms/step - loss: -72.9085 - accuracy: 0.9877 - precision: 1.0000 - recall: 0.9990
# Epoch 10/15
# 2012/2012 [==============================] - 677s 337ms/step - loss: -81.8473 - accuracy: 0.9877 - precision: 1.0000 - recall: 0.9990
# Epoch 11/15
# 2012/2012 [==============================] - 678s 337ms/step - loss: -90.8172 - accuracy: 0.9877 - precision: 1.0000 - recall: 0.9990
# Epoch 12/15
# 2012/2012 [==============================] - 678s 337ms/step - loss: -99.5005 - accuracy: 0.9877 - precision: 1.0000 - recall: 0.9990
# Epoch 13/15
# 2012/2012 [==============================] - 677s 336ms/step - loss: -108.4496 - accuracy: 0.9878 - precision: 1.0000 - recall: 0.9991
# Epoch 14/15
# 2012/2012 [==============================] - 676s 336ms/step - loss: -117.2521 - accuracy: 0.9877 - precision: 1.0000 - recall: 0.9990
# Epoch 15/15
# 2012/2012 [==============================] - 677s 336ms/step - loss: -126.1084 - accuracy: 0.9877 - precision: 1.0000 - recall: 0.9990

# %%
y_predicted = model.predict(X_test)
y_predicted = y_predicted.flatten()

# %%
y_predicted = np.where(y_predicted > 0.5, 1, 0)
y_predicted
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
sample_dataset = ['Why would you want to do that? There are a lot of uses for sentiment analysis, such as understanding how stock traders feel about a particular company by using social media']

# %%
model.predict(sample_dataset)
# Out:
# array([[1.]], dtype=float32)
